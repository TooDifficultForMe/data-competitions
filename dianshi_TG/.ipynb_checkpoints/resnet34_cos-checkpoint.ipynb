# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '2'
import torch
import torch.nn as nn
import numpy as np
from torchvision import models, transforms
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
from data import data_reader

Tensor = torch.Tensor
rand_m = np.random.random

# %%
MODEL_NAME = 'resnet34_cos'
if not os.path.exists('weights/'):
    # !mkdir weights
if not os.path.exists('weights/{}'.format(MODEL_NAME)):
    # !mkdir weights/{MODEL_NAME}

# %%
from models import model_resnet34

# %%
model = model_resnet34(6).to('cuda')

# %%
optim = torch.optim.Adam(model.parameters())
loss_func = torch.nn.CrossEntropyLoss()

# %%
from data import data_reader
class args:
    bs = 256
    path = 'train2000/'

dr = data_reader(args, 'train2000/train2000.csv')

train_loader, test_loader = dr.get_train_loader()

# %%
from utils.train_model import cyc_trainer

# %%
resnet34_cyc_trainer = cyc_trainer(model, 2, 2, train_loader=train_loader, test_loader=test_loader, 
                                  optim=optim, loss_func=loss_func, model_name='resnet34_cos', save=False)

# %%
resnet34_cyc_trainer.train()
# Out:
# Snapshot#  0
# Cycle 0 | Epoch # 0 | lr = 0.001
# Cycle 0 | Epoch 0 | Batch # 0 Train Loss 1.96324
# Cycle 0 | Epoch 0 | Batch # 1 Train Loss 0.49962
# Cycle 0 | Epoch 0 | Batch # 2 Train Loss 0.51580
# Cycle 0 | Epoch 0 | Batch # 3 Train Loss 0.56814
# Cycle 0 | Epoch 0 | Batch # 4 Train Loss 0.46213
# Cycle 0 | Epoch 0 | Batch # 5 Train Loss 0.30492
# Cycle 0 | Epoch 0 | Batch # 6 Train Loss 0.62622
# Cycle 0 | Epoch 0 | Epoch Train Loss 0.70572
#
# Cycle 0 | Epoch 0 | Epoch Train Acc 73.250%
# Cycle 0 | Epoch 0 | Epoch Val Loss 0.56878
# Cycle 0 | Epoch 0 | Epoch Val Acc 80.250%
# Cycle 0 | Epoch # 1 | lr = 0.0008117449009293668
# Cycle 0 | Epoch 1 | Batch # 0 Train Loss 0.48657
# Cycle 0 | Epoch 1 | Batch # 1 Train Loss 0.36978
# Cycle 0 | Epoch 1 | Batch # 2 Train Loss 0.29306
# Cycle 0 | Epoch 1 | Batch # 3 Train Loss 0.38586
# Cycle 0 | Epoch 1 | Batch # 4 Train Loss 0.25417
# Cycle 0 | Epoch 1 | Batch # 5 Train Loss 0.17060
# Cycle 0 | Epoch 1 | Batch # 6 Train Loss 0.42265
# Cycle 0 | Epoch 1 | Epoch Train Loss 0.34038
#
# Cycle 0 | Epoch 1 | Epoch Train Acc 88.750%
# Cycle 0 | Epoch 1 | Epoch Val Loss 0.35084
# Cycle 0 | Epoch 1 | Epoch Val Acc 88.500%
# Cycle 0 | Epoch # 2 | lr = 0.00038873953302184284
# Cycle 0 | Epoch 2 | Batch # 0 Train Loss 0.16834
# Cycle 0 | Epoch 2 | Batch # 1 Train Loss 0.31711
# Cycle 0 | Epoch 2 | Batch # 2 Train Loss 0.22872
# Cycle 0 | Epoch 2 | Batch # 3 Train Loss 0.27334
# Cycle 0 | Epoch 2 | Batch # 4 Train Loss 0.15130
# Cycle 0 | Epoch 2 | Batch # 5 Train Loss 0.18237
# Cycle 0 | Epoch 2 | Batch # 6 Train Loss 0.54700
# Cycle 0 | Epoch 2 | Epoch Train Loss 0.26688
#
# Cycle 0 | Epoch 2 | Epoch Train Acc 92.375%
# Cycle 0 | Epoch 2 | Epoch Val Loss 0.28164
# Cycle 0 | Epoch 2 | Epoch Val Acc 92.500%
# Snapshot#  1
# Cycle 1 | Epoch # 0 | lr = 0.001
# Cycle 1 | Epoch 0 | Batch # 0 Train Loss 0.13967
# Cycle 1 | Epoch 0 | Batch # 1 Train Loss 0.18480
# Cycle 1 | Epoch 0 | Batch # 2 Train Loss 0.19139
# Cycle 1 | Epoch 0 | Batch # 3 Train Loss 0.22265
# Cycle 1 | Epoch 0 | Batch # 4 Train Loss 0.18067
# Cycle 1 | Epoch 0 | Batch # 5 Train Loss 0.19608
# Cycle 1 | Epoch 0 | Batch # 6 Train Loss 0.10348
# Cycle 1 | Epoch 0 | Epoch Train Loss 0.17411
#
# Cycle 1 | Epoch 0 | Epoch Train Acc 93.438%
# Cycle 1 | Epoch 0 | Epoch Val Loss 0.22416
# Cycle 1 | Epoch 0 | Epoch Val Acc 92.500%
# Cycle 1 | Epoch # 1 | lr = 0.0009272097022732444
# Cycle 1 | Epoch 1 | Batch # 0 Train Loss 0.11359
# Cycle 1 | Epoch 1 | Batch # 1 Train Loss 0.13720
# Cycle 1 | Epoch 1 | Batch # 2 Train Loss 0.14876
# Cycle 1 | Epoch 1 | Batch # 3 Train Loss 0.11468
# Cycle 1 | Epoch 1 | Batch # 4 Train Loss 0.11874
# Cycle 1 | Epoch 1 | Batch # 5 Train Loss 0.06461
# Cycle 1 | Epoch 1 | Batch # 6 Train Loss 0.10891
# Cycle 1 | Epoch 1 | Epoch Train Loss 0.11521
#
# Cycle 1 | Epoch 1 | Epoch Train Acc 95.938%
# Cycle 1 | Epoch 1 | Epoch Val Loss 0.28918
# Cycle 1 | Epoch 1 | Epoch Val Acc 92.000%
# Cycle 1 | Epoch # 2 | lr = 0.0007300325188655761
# Cycle 1 | Epoch 2 | Batch # 0 Train Loss 0.08706
# Cycle 1 | Epoch 2 | Batch # 1 Train Loss 0.11242
# Cycle 1 | Epoch 2 | Batch # 2 Train Loss 0.10738
# Cycle 1 | Epoch 2 | Batch # 3 Train Loss 0.11784
# Cycle 1 | Epoch 2 | Batch # 4 Train Loss 0.09676
# Cycle 1 | Epoch 2 | Batch # 5 Train Loss 0.09867
# Cycle 1 | Epoch 2 | Batch # 6 Train Loss 0.18949
# Cycle 1 | Epoch 2 | Epoch Train Loss 0.11566
#
# Cycle 1 | Epoch 2 | Epoch Train Acc 96.375%
# Cycle 1 | Epoch 2 | Epoch Val Loss 0.25429
# Cycle 1 | Epoch 2 | Epoch Val Acc 92.750%
# Cycle 1 | Epoch # 3 | lr = 0.00046587879331766457
# Cycle 1 | Epoch 3 | Batch # 0 Train Loss 0.14580
# Cycle 1 | Epoch 3 | Batch # 1 Train Loss 0.15654
# Cycle 1 | Epoch 3 | Batch # 2 Train Loss 0.07296
# Cycle 1 | Epoch 3 | Batch # 3 Train Loss 0.08563
# Cycle 1 | Epoch 3 | Batch # 4 Train Loss 0.17260
# Cycle 1 | Epoch 3 | Batch # 5 Train Loss 0.07581
# Cycle 1 | Epoch 3 | Batch # 6 Train Loss 0.07269
# Cycle 1 | Epoch 3 | Epoch Train Loss 0.11172
#
# Cycle 1 | Epoch 3 | Epoch Train Acc 96.188%
# Cycle 1 | Epoch 3 | Epoch Val Loss 0.19056
# Cycle 1 | Epoch 3 | Epoch Val Acc 94.000%
# Cycle 1 | Epoch # 4 | lr = 0.00021165983894256646
# Cycle 1 | Epoch 4 | Batch # 0 Train Loss 0.09598
# Cycle 1 | Epoch 4 | Batch # 1 Train Loss 0.12615
# Cycle 1 | Epoch 4 | Batch # 2 Train Loss 0.11485
# Cycle 1 | Epoch 4 | Batch # 3 Train Loss 0.07081
# Cycle 1 | Epoch 4 | Batch # 4 Train Loss 0.13416
# Cycle 1 | Epoch 4 | Batch # 5 Train Loss 0.10066
# Cycle 1 | Epoch 4 | Batch # 6 Train Loss 0.02136
# Cycle 1 | Epoch 4 | Epoch Train Loss 0.09485
#
# Cycle 1 | Epoch 4 | Epoch Train Acc 96.625%
# Cycle 1 | Epoch 4 | Epoch Val Loss 0.15341
# Cycle 1 | Epoch 4 | Epoch Val Acc 95.000%

# %%
resnet34_cyc_trainer.plot_loss()

# %%
resnet34_cyc_trainer.plot_acc()

# %%
resnet34_cyc_trainer.plot_lr()
