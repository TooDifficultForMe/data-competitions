# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '1'
import torch
import torch.nn as nn
import numpy as np
from torchvision import models
import matplotlib.pyplot as plt

Tensor = torch.Tensor
rand_m = np.random.random

# %%
class model_resnet(nn.Module):
    def __init__(self, num_class):
        super(model_resnet, self).__init__()
        self.resnet = models.resnet50(pretrained=True)
        self.argp = nn.AdaptiveAvgPool2d(1)
        self.fc = nn.Sequential(nn.Linear(2048, 512), nn.ReLU(inplace=True), nn.Linear(512, num_class))
    
    def forward(self, x):
        x = self.resnet.conv1(x)
        x = self.resnet.bn1(x)
        x = self.resnet.relu(x)
        x = self.resnet.maxpool(x)
        x = self.resnet.layer1(x)
        x = self.resnet.layer2(x)
        x = self.resnet.layer3(x)
        x = self.resnet.layer4(x)
        x = self.argp(x)
        x = x.view(x.size(0), -1)
        x = self.fc(x)
        return x

# %%
resnet = model_resnet(6).to('cuda')

# %%
optim = torch.optim.Adam(resnet.parameters())
loss_func = torch.nn.CrossEntropyLoss()

# %%
from data import data_reader
class args:
    bs = 64
    path = 'train2000/'

# %%
dr = data_reader(args, 'train2000/train2000.csv')

# %%
train_loader, test_loader = dr.get_train_loader()

# %%
train_loss_rec = []
train_acc_rec = []
test_loss_rec = []
test_acc_rec = []
best_acc = 0
for epoch in range(50):
    epoch_loss = 0
    total, correct = 0, 0
    for batch_idx, (X_train, y_train) in enumerate(train_loader):
        X_train, y_train = X_train.to('cuda'), y_train.to('cuda')
        optim.zero_grad()
        y_hat = resnet(X_train)
        loss = loss_func(y_hat, torch.max(y_train, 1)[1])
        loss.backward()
        _, pred = torch.max(y_hat.data, 1)
        optim.step()
        correct += (pred == torch.max(y_train, 1)[1]).sum().item()
        total += X_train.size(0)
        epoch_loss += loss.item() / len(train_loader)
        print('\rEpoch {} | Batch # {} Train Loss {:.5f} '.format(epoch, batch_idx, loss.item()))
    print('\rEpoch {} | Epoch Train Loss {:.5f}'.format(epoch, epoch_loss))
    epoch_acc = correct / total * 100
    print('\nEpoch {} | Epoch Train Acc {:.3f}%'.format(epoch, epoch_acc))
    train_loss_rec.append(epoch_loss)
    train_acc_rec.append(epoch_acc)
    with torch.no_grad():
        test_epoch_loss = 0
        test_total = 0
        test_correct = 0
            
        for batch_idx, (X_val, y_val) in enumerate(test_loader):
            X_val, y_val = X_val.to('cuda'), y_val.to('cuda')
            
            y_hat = resnet(X_val)
            loss = loss_func(y_hat, torch.max(y_val, 1)[1])
            _, pred = torch.max(y_hat.data, 1)
                
            test_total += y_val.size(0)
            test_correct += (pred == torch.max(y_val, 1)[1]).sum().item()
            test_epoch_loss += loss.item() / len(test_loader)
             
        test_epoch_acc = test_correct / test_total * 100
        if test_epoch_acc > best_acc:
            best_acc = test_epoch_acc
            torch.save(resnet.state_dict(), 'weights/resnet50/best_params_acc{}.pth'.format(best_acc)) 
        print('Epoch {} | Epoch Val Loss {:.5f}'.format(epoch, test_epoch_loss))
        print('Epoch {} | Epoch Val Acc {:.3f}%'.format(epoch, test_epoch_acc))
            
        test_loss_rec.append(test_epoch_loss)
        test_acc_rec.append(test_epoch_acc)
# Out:
# Epoch 0 | Batch # 0 Train Loss 1.81442
# Epoch 0 | Batch # 1 Train Loss 1.18170
# Epoch 0 | Batch # 2 Train Loss 1.31162
# Epoch 0 | Batch # 3 Train Loss 0.66013
# Epoch 0 | Batch # 4 Train Loss 0.62375
# Epoch 0 | Batch # 5 Train Loss 1.18414
# Epoch 0 | Batch # 6 Train Loss 0.71423
# Epoch 0 | Batch # 7 Train Loss 1.46510
# Epoch 0 | Batch # 8 Train Loss 0.82267
# Epoch 0 | Batch # 9 Train Loss 0.99096
# Epoch 0 | Batch # 10 Train Loss 1.22168
# Epoch 0 | Batch # 11 Train Loss 0.93945
# Epoch 0 | Batch # 12 Train Loss 0.73731
# Epoch 0 | Batch # 13 Train Loss 0.54321
# Epoch 0 | Batch # 14 Train Loss 0.69570
# Epoch 0 | Batch # 15 Train Loss 0.64582
# Epoch 0 | Batch # 16 Train Loss 0.78163
# Epoch 0 | Batch # 17 Train Loss 0.73963
# Epoch 0 | Batch # 18 Train Loss 0.60611
# Epoch 0 | Batch # 19 Train Loss 0.69627
# Epoch 0 | Batch # 20 Train Loss 0.35610
# Epoch 0 | Batch # 21 Train Loss 0.46459
# Epoch 0 | Batch # 22 Train Loss 0.67723
# Epoch 0 | Batch # 23 Train Loss 0.33487
# Epoch 0 | Batch # 24 Train Loss 0.39309
# Epoch 0 | Epoch Train Loss 0.82406
#
# Epoch 0 | Epoch Train Acc 73.562%
# Epoch 0 | Epoch Val Loss 0.45648
# Epoch 0 | Epoch Val Acc 84.000%
# Epoch 1 | Batch # 0 Train Loss 0.16613
# Epoch 1 | Batch # 1 Train Loss 0.33172
# Epoch 1 | Batch # 2 Train Loss 0.46115
# Epoch 1 | Batch # 3 Train Loss 1.03095
# Epoch 1 | Batch # 4 Train Loss 0.44316
# Epoch 1 | Batch # 5 Train Loss 0.37294
# Epoch 1 | Batch # 6 Train Loss 0.40985
# Epoch 1 | Batch # 7 Train Loss 0.34804
# Epoch 1 | Batch # 8 Train Loss 0.43622
# Epoch 1 | Batch # 9 Train Loss 0.54164
# Epoch 1 | Batch # 10 Train Loss 0.35536
# Epoch 1 | Batch # 11 Train Loss 0.32734
# Epoch 1 | Batch # 12 Train Loss 0.59822
# Epoch 1 | Batch # 13 Train Loss 0.31896
# Epoch 1 | Batch # 14 Train Loss 0.48144
# Epoch 1 | Batch # 15 Train Loss 0.55739
# Epoch 1 | Batch # 16 Train Loss 0.33774
# Epoch 1 | Batch # 17 Train Loss 0.26289
# Epoch 1 | Batch # 18 Train Loss 0.17911
# Epoch 1 | Batch # 19 Train Loss 0.36942
# Epoch 1 | Batch # 20 Train Loss 0.70080
# Epoch 1 | Batch # 21 Train Loss 0.23291
# Epoch 1 | Batch # 22 Train Loss 0.45206
# Epoch 1 | Batch # 23 Train Loss 0.34036
# Epoch 1 | Batch # 24 Train Loss 0.27017
# Epoch 1 | Epoch Train Loss 0.41304
#
# Epoch 1 | Epoch Train Acc 87.000%
# Epoch 1 | Epoch Val Loss 0.38141
# Epoch 1 | Epoch Val Acc 85.500%
# Epoch 2 | Batch # 0 Train Loss 0.27085
# Epoch 2 | Batch # 1 Train Loss 0.44578
# Epoch 2 | Batch # 2 Train Loss 0.24510
# Epoch 2 | Batch # 3 Train Loss 0.36390
# Epoch 2 | Batch # 4 Train Loss 0.31585
# Epoch 2 | Batch # 5 Train Loss 0.43860
# Epoch 2 | Batch # 6 Train Loss 0.24971
# Epoch 2 | Batch # 7 Train Loss 0.41586
# Epoch 2 | Batch # 8 Train Loss 0.38895
# Epoch 2 | Batch # 9 Train Loss 0.33587
# Epoch 2 | Batch # 10 Train Loss 0.51166
# Epoch 2 | Batch # 11 Train Loss 0.25997
# Epoch 2 | Batch # 12 Train Loss 0.33482
# Epoch 2 | Batch # 13 Train Loss 0.39662
# Epoch 2 | Batch # 14 Train Loss 0.43283
# Epoch 2 | Batch # 15 Train Loss 0.12081
# Epoch 2 | Batch # 16 Train Loss 0.39201
# Epoch 2 | Batch # 17 Train Loss 0.27177
# Epoch 2 | Batch # 18 Train Loss 0.52800
# Epoch 2 | Batch # 19 Train Loss 0.22385
# Epoch 2 | Batch # 20 Train Loss 0.22007
# Epoch 2 | Batch # 21 Train Loss 0.34562
# Epoch 2 | Batch # 22 Train Loss 0.36934
# Epoch 2 | Batch # 23 Train Loss 0.23720
# Epoch 2 | Batch # 24 Train Loss 0.30959
# Epoch 2 | Epoch Train Loss 0.33699
#
# Epoch 2 | Epoch Train Acc 88.625%
# Epoch 2 | Epoch Val Loss 0.37309
# Epoch 2 | Epoch Val Acc 86.250%
# Epoch 3 | Batch # 0 Train Loss 0.21194
# Epoch 3 | Batch # 1 Train Loss 0.19147
# Epoch 3 | Batch # 2 Train Loss 0.36144
# Epoch 3 | Batch # 3 Train Loss 0.29794
# Epoch 3 | Batch # 4 Train Loss 0.44575
# Epoch 3 | Batch # 5 Train Loss 0.34506
# Epoch 3 | Batch # 6 Train Loss 0.19641
# Epoch 3 | Batch # 7 Train Loss 0.44605
# Epoch 3 | Batch # 8 Train Loss 0.29200
# Epoch 3 | Batch # 9 Train Loss 0.30269
# Epoch 3 | Batch # 10 Train Loss 0.39433
# Epoch 3 | Batch # 11 Train Loss 0.21771
# Epoch 3 | Batch # 12 Train Loss 0.41353
# Epoch 3 | Batch # 13 Train Loss 0.20546
# Epoch 3 | Batch # 14 Train Loss 0.24952
# Epoch 3 | Batch # 15 Train Loss 0.41878
# Epoch 3 | Batch # 16 Train Loss 0.24020
# Epoch 3 | Batch # 17 Train Loss 0.41441
# Epoch 3 | Batch # 18 Train Loss 0.27950
# Epoch 3 | Batch # 19 Train Loss 0.22449
# Epoch 3 | Batch # 20 Train Loss 0.12420
# Epoch 3 | Batch # 21 Train Loss 0.15568
# Epoch 3 | Batch # 22 Train Loss 0.32270
# Epoch 3 | Batch # 23 Train Loss 0.29184
# Epoch 3 | Batch # 24 Train Loss 0.46245
# Epoch 3 | Epoch Train Loss 0.30022
#
# Epoch 3 | Epoch Train Acc 89.938%
# Epoch 3 | Epoch Val Loss 0.29749
# Epoch 3 | Epoch Val Acc 91.500%
# Epoch 4 | Batch # 0 Train Loss 0.16729
# Epoch 4 | Batch # 1 Train Loss 0.26611
# Epoch 4 | Batch # 2 Train Loss 0.19989
# Epoch 4 | Batch # 3 Train Loss 0.28469
# Epoch 4 | Batch # 4 Train Loss 0.18305
# Epoch 4 | Batch # 5 Train Loss 0.08832
# Epoch 4 | Batch # 6 Train Loss 0.17818
# Epoch 4 | Batch # 7 Train Loss 0.25217
# Epoch 4 | Batch # 8 Train Loss 0.26312
# Epoch 4 | Batch # 9 Train Loss 0.25096
# Epoch 4 | Batch # 10 Train Loss 0.33758
# Epoch 4 | Batch # 11 Train Loss 0.16802
# Epoch 4 | Batch # 12 Train Loss 0.27181
# Epoch 4 | Batch # 13 Train Loss 0.21716
# Epoch 4 | Batch # 14 Train Loss 0.30992
# Epoch 4 | Batch # 15 Train Loss 0.16909
# Epoch 4 | Batch # 16 Train Loss 0.33473
# Epoch 4 | Batch # 17 Train Loss 0.05440
# Epoch 4 | Batch # 18 Train Loss 0.25539
# Epoch 4 | Batch # 19 Train Loss 0.41461
# Epoch 4 | Batch # 20 Train Loss 0.08795
# Epoch 4 | Batch # 21 Train Loss 0.24492
# Epoch 4 | Batch # 22 Train Loss 0.31673
# Epoch 4 | Batch # 23 Train Loss 0.17407
# Epoch 4 | Batch # 24 Train Loss 0.32945
# Epoch 4 | Epoch Train Loss 0.23278
#
# Epoch 4 | Epoch Train Acc 91.875%
# Epoch 4 | Epoch Val Loss 0.35702
# Epoch 4 | Epoch Val Acc 88.500%
# Epoch 5 | Batch # 0 Train Loss 0.41513
# Epoch 5 | Batch # 1 Train Loss 0.22961
# Epoch 5 | Batch # 2 Train Loss 0.28334
# Epoch 5 | Batch # 3 Train Loss 0.33121
# Epoch 5 | Batch # 4 Train Loss 0.20699
# Epoch 5 | Batch # 5 Train Loss 0.13435
# Epoch 5 | Batch # 6 Train Loss 0.29012
# Epoch 5 | Batch # 7 Train Loss 0.11531
# Epoch 5 | Batch # 8 Train Loss 0.15605
# Epoch 5 | Batch # 9 Train Loss 0.16199
# Epoch 5 | Batch # 10 Train Loss 0.31011
# Epoch 5 | Batch # 11 Train Loss 0.17606
# Epoch 5 | Batch # 12 Train Loss 0.24259
# Epoch 5 | Batch # 13 Train Loss 0.12557
# Epoch 5 | Batch # 14 Train Loss 0.14457
# Epoch 5 | Batch # 15 Train Loss 0.12313
# Epoch 5 | Batch # 16 Train Loss 0.19684
# Epoch 5 | Batch # 17 Train Loss 0.10378
# Epoch 5 | Batch # 18 Train Loss 0.06666
# Epoch 5 | Batch # 19 Train Loss 0.31568
# Epoch 5 | Batch # 20 Train Loss 0.15165
# Epoch 5 | Batch # 21 Train Loss 0.23446
# Epoch 5 | Batch # 22 Train Loss 0.11296
# Epoch 5 | Batch # 23 Train Loss 0.11366
# Epoch 5 | Batch # 24 Train Loss 0.16349
# Epoch 5 | Epoch Train Loss 0.19621
#
# Epoch 5 | Epoch Train Acc 94.062%
# Epoch 5 | Epoch Val Loss 0.33837
# Epoch 5 | Epoch Val Acc 89.000%
# Epoch 6 | Batch # 0 Train Loss 0.23755
# Epoch 6 | Batch # 1 Train Loss 0.19244
# Epoch 6 | Batch # 2 Train Loss 0.22290
# Epoch 6 | Batch # 3 Train Loss 0.14719
# Epoch 6 | Batch # 4 Train Loss 0.16220
# Epoch 6 | Batch # 5 Train Loss 0.09723
# Epoch 6 | Batch # 6 Train Loss 0.09903
# Epoch 6 | Batch # 7 Train Loss 0.12629
# Epoch 6 | Batch # 8 Train Loss 0.24407
# Epoch 6 | Batch # 9 Train Loss 0.29331
# Epoch 6 | Batch # 10 Train Loss 0.13493
# Epoch 6 | Batch # 11 Train Loss 0.12736
# Epoch 6 | Batch # 12 Train Loss 0.19771
# Epoch 6 | Batch # 13 Train Loss 0.19732
# Epoch 6 | Batch # 14 Train Loss 0.35756
# Epoch 6 | Batch # 15 Train Loss 0.16797
# Epoch 6 | Batch # 16 Train Loss 0.11819
# Epoch 6 | Batch # 17 Train Loss 0.21385
# Epoch 6 | Batch # 18 Train Loss 0.20362
# Epoch 6 | Batch # 19 Train Loss 0.10969
# Epoch 6 | Batch # 20 Train Loss 0.20003
# Epoch 6 | Batch # 21 Train Loss 0.22026
# Epoch 6 | Batch # 22 Train Loss 0.09195
# Epoch 6 | Batch # 23 Train Loss 0.12074
# Epoch 6 | Batch # 24 Train Loss 0.24423
# Epoch 6 | Epoch Train Loss 0.18111
#
# Epoch 6 | Epoch Train Acc 94.000%
# Epoch 6 | Epoch Val Loss 0.35425
# Epoch 6 | Epoch Val Acc 88.000%
# Epoch 7 | Batch # 0 Train Loss 0.20108
# Epoch 7 | Batch # 1 Train Loss 0.15345
# Epoch 7 | Batch # 2 Train Loss 0.40008
# Epoch 7 | Batch # 3 Train Loss 0.06649
# Epoch 7 | Batch # 4 Train Loss 0.12010
# Epoch 7 | Batch # 5 Train Loss 0.21922
# Epoch 7 | Batch # 6 Train Loss 0.20246
# Epoch 7 | Batch # 7 Train Loss 0.18108
# Epoch 7 | Batch # 8 Train Loss 0.19762
# Epoch 7 | Batch # 9 Train Loss 0.12450
# Epoch 7 | Batch # 10 Train Loss 0.14266
# Epoch 7 | Batch # 11 Train Loss 0.16440
# Epoch 7 | Batch # 12 Train Loss 0.13560
# Epoch 7 | Batch # 13 Train Loss 0.06633
# Epoch 7 | Batch # 14 Train Loss 0.28118
# Epoch 7 | Batch # 15 Train Loss 0.06000
# Epoch 7 | Batch # 16 Train Loss 0.43087
# Epoch 7 | Batch # 17 Train Loss 0.16648
# Epoch 7 | Batch # 18 Train Loss 0.19106
# Epoch 7 | Batch # 19 Train Loss 0.21854
# Epoch 7 | Batch # 20 Train Loss 0.22188
# Epoch 7 | Batch # 21 Train Loss 0.14503
# Epoch 7 | Batch # 22 Train Loss 0.15910
# Epoch 7 | Batch # 23 Train Loss 0.10815
# Epoch 7 | Batch # 24 Train Loss 0.22459
# Epoch 7 | Epoch Train Loss 0.18328
#
# Epoch 7 | Epoch Train Acc 94.312%
# Epoch 7 | Epoch Val Loss 0.28787
# Epoch 7 | Epoch Val Acc 91.750%
# Epoch 8 | Batch # 0 Train Loss 0.14069
# Epoch 8 | Batch # 1 Train Loss 0.26160
# Epoch 8 | Batch # 2 Train Loss 0.17314
# Epoch 8 | Batch # 3 Train Loss 0.17425
# Epoch 8 | Batch # 4 Train Loss 0.24975
# Epoch 8 | Batch # 5 Train Loss 0.18811
# Epoch 8 | Batch # 6 Train Loss 0.17512
# Epoch 8 | Batch # 7 Train Loss 0.17486
# Epoch 8 | Batch # 8 Train Loss 0.07421
# Epoch 8 | Batch # 9 Train Loss 0.17418
# Epoch 8 | Batch # 10 Train Loss 0.19580
# Epoch 8 | Batch # 11 Train Loss 0.09004
# Epoch 8 | Batch # 12 Train Loss 0.28345
# Epoch 8 | Batch # 13 Train Loss 0.09312
# Epoch 8 | Batch # 14 Train Loss 0.22491
# Epoch 8 | Batch # 15 Train Loss 0.14065
# Epoch 8 | Batch # 16 Train Loss 0.14005
# Epoch 8 | Batch # 17 Train Loss 0.40219
# Epoch 8 | Batch # 18 Train Loss 0.11155
# Epoch 8 | Batch # 19 Train Loss 0.18770
# Epoch 8 | Batch # 20 Train Loss 0.12328
# Epoch 8 | Batch # 21 Train Loss 0.19727
# Epoch 8 | Batch # 22 Train Loss 0.15811
# Epoch 8 | Batch # 23 Train Loss 0.08195
# Epoch 8 | Batch # 24 Train Loss 0.05489
# Epoch 8 | Epoch Train Loss 0.17083
#
# Epoch 8 | Epoch Train Acc 94.438%
# Epoch 8 | Epoch Val Loss 0.19889
# Epoch 8 | Epoch Val Acc 92.000%
# Epoch 9 | Batch # 0 Train Loss 0.17887
# Epoch 9 | Batch # 1 Train Loss 0.15880
# Epoch 9 | Batch # 2 Train Loss 0.15745
# Epoch 9 | Batch # 3 Train Loss 0.23386
# Epoch 9 | Batch # 4 Train Loss 0.32998
# Epoch 9 | Batch # 5 Train Loss 0.31771
# Epoch 9 | Batch # 6 Train Loss 0.21123
# Epoch 9 | Batch # 7 Train Loss 0.12484
# Epoch 9 | Batch # 8 Train Loss 0.20027
# Epoch 9 | Batch # 9 Train Loss 0.24272
# Epoch 9 | Batch # 10 Train Loss 0.07770
# Epoch 9 | Batch # 11 Train Loss 0.15839
# Epoch 9 | Batch # 12 Train Loss 0.11244
# Epoch 9 | Batch # 13 Train Loss 0.17820
# Epoch 9 | Batch # 14 Train Loss 0.29680
# Epoch 9 | Batch # 15 Train Loss 0.05274
# Epoch 9 | Batch # 16 Train Loss 0.16160
# Epoch 9 | Batch # 17 Train Loss 0.20913
# Epoch 9 | Batch # 18 Train Loss 0.16486
# Epoch 9 | Batch # 19 Train Loss 0.19269
# Epoch 9 | Batch # 20 Train Loss 0.29537
# Epoch 9 | Batch # 21 Train Loss 0.08602
# Epoch 9 | Batch # 22 Train Loss 0.27479
# Epoch 9 | Batch # 23 Train Loss 0.13810
# Epoch 9 | Batch # 24 Train Loss 0.23243
# Epoch 9 | Epoch Train Loss 0.19148
#
# Epoch 9 | Epoch Train Acc 93.938%
# Epoch 9 | Epoch Val Loss 0.27614
# Epoch 9 | Epoch Val Acc 90.000%
# Epoch 10 | Batch # 0 Train Loss 0.23258
# Epoch 10 | Batch # 1 Train Loss 0.08696
# Epoch 10 | Batch # 2 Train Loss 0.49162
# Epoch 10 | Batch # 3 Train Loss 0.27205
# Epoch 10 | Batch # 4 Train Loss 0.11282
# Epoch 10 | Batch # 5 Train Loss 0.09016
# Epoch 10 | Batch # 6 Train Loss 0.13055
# Epoch 10 | Batch # 7 Train Loss 0.15254
# Epoch 10 | Batch # 8 Train Loss 0.13631
# Epoch 10 | Batch # 9 Train Loss 0.32606
# Epoch 10 | Batch # 10 Train Loss 0.05919
# Epoch 10 | Batch # 11 Train Loss 0.12035
# Epoch 10 | Batch # 12 Train Loss 0.38210
# Epoch 10 | Batch # 13 Train Loss 0.15707
# Epoch 10 | Batch # 14 Train Loss 0.27402
# Epoch 10 | Batch # 15 Train Loss 0.51155
# Epoch 10 | Batch # 16 Train Loss 0.32484
# Epoch 10 | Batch # 17 Train Loss 0.13610
# Epoch 10 | Batch # 18 Train Loss 0.23499
# Epoch 10 | Batch # 19 Train Loss 0.21276
# Epoch 10 | Batch # 20 Train Loss 0.30394
# Epoch 10 | Batch # 21 Train Loss 0.21952
# Epoch 10 | Batch # 22 Train Loss 0.23742
# Epoch 10 | Batch # 23 Train Loss 0.31070
# Epoch 10 | Batch # 24 Train Loss 0.20754
# Epoch 10 | Epoch Train Loss 0.22895
#
# Epoch 10 | Epoch Train Acc 93.062%
# Epoch 10 | Epoch Val Loss 0.19311
# Epoch 10 | Epoch Val Acc 92.750%
# Epoch 11 | Batch # 0 Train Loss 0.10442
# Epoch 11 | Batch # 1 Train Loss 0.13807
# Epoch 11 | Batch # 2 Train Loss 0.15550
# Epoch 11 | Batch # 3 Train Loss 0.16419
# Epoch 11 | Batch # 4 Train Loss 0.09641
# Epoch 11 | Batch # 5 Train Loss 0.20019
# Epoch 11 | Batch # 6 Train Loss 0.05806
# Epoch 11 | Batch # 7 Train Loss 0.12314
# Epoch 11 | Batch # 8 Train Loss 0.09907
# Epoch 11 | Batch # 9 Train Loss 0.16400
# Epoch 11 | Batch # 10 Train Loss 0.07105
# Epoch 11 | Batch # 11 Train Loss 0.10533
# Epoch 11 | Batch # 12 Train Loss 0.28458
# Epoch 11 | Batch # 13 Train Loss 0.34737
# Epoch 11 | Batch # 14 Train Loss 0.08343
# Epoch 11 | Batch # 15 Train Loss 0.09177
# Epoch 11 | Batch # 16 Train Loss 0.04502
# Epoch 11 | Batch # 17 Train Loss 0.11050
# Epoch 11 | Batch # 18 Train Loss 0.05863
# Epoch 11 | Batch # 19 Train Loss 0.18477
# Epoch 11 | Batch # 20 Train Loss 0.14785
# Epoch 11 | Batch # 21 Train Loss 0.05510
# Epoch 11 | Batch # 22 Train Loss 0.14351
# Epoch 11 | Batch # 23 Train Loss 0.32005
# Epoch 11 | Batch # 24 Train Loss 0.09675
# Epoch 11 | Epoch Train Loss 0.13795
#
# Epoch 11 | Epoch Train Acc 94.938%
# Epoch 11 | Epoch Val Loss 0.21030
# Epoch 11 | Epoch Val Acc 95.750%
# Epoch 12 | Batch # 0 Train Loss 0.17689
# Epoch 12 | Batch # 1 Train Loss 0.08880
# Epoch 12 | Batch # 2 Train Loss 0.15360
# Epoch 12 | Batch # 3 Train Loss 0.05940
# Epoch 12 | Batch # 4 Train Loss 0.15523
# Epoch 12 | Batch # 5 Train Loss 0.11215
# Epoch 12 | Batch # 6 Train Loss 0.10905
# Epoch 12 | Batch # 7 Train Loss 0.17811
# Epoch 12 | Batch # 8 Train Loss 0.14684
# Epoch 12 | Batch # 9 Train Loss 0.07646
# Epoch 12 | Batch # 10 Train Loss 0.16079
# Epoch 12 | Batch # 11 Train Loss 0.14991
# Epoch 12 | Batch # 12 Train Loss 0.12942
# Epoch 12 | Batch # 13 Train Loss 0.09111
# Epoch 12 | Batch # 14 Train Loss 0.14654
# Epoch 12 | Batch # 15 Train Loss 0.06142
# Epoch 12 | Batch # 16 Train Loss 0.16404
# Epoch 12 | Batch # 17 Train Loss 0.29967
# Epoch 12 | Batch # 18 Train Loss 0.19793
# Epoch 12 | Batch # 19 Train Loss 0.07926
# Epoch 12 | Batch # 20 Train Loss 0.16176
# Epoch 12 | Batch # 21 Train Loss 0.07796
# Epoch 12 | Batch # 22 Train Loss 0.07813
# Epoch 12 | Batch # 23 Train Loss 0.13394
# Epoch 12 | Batch # 24 Train Loss 0.07018
# Epoch 12 | Epoch Train Loss 0.13034
#
# Epoch 12 | Epoch Train Acc 95.438%
# Epoch 12 | Epoch Val Loss 0.21992
# Epoch 12 | Epoch Val Acc 91.750%
# Epoch 13 | Batch # 0 Train Loss 0.10550
# Epoch 13 | Batch # 1 Train Loss 0.05973
# Epoch 13 | Batch # 2 Train Loss 0.19129
# Epoch 13 | Batch # 3 Train Loss 0.23672
# Epoch 13 | Batch # 4 Train Loss 0.11846
# Epoch 13 | Batch # 5 Train Loss 0.07979
# Epoch 13 | Batch # 6 Train Loss 0.06022
# Epoch 13 | Batch # 7 Train Loss 0.11551
# Epoch 13 | Batch # 8 Train Loss 0.03037
# Epoch 13 | Batch # 9 Train Loss 0.08235
# Epoch 13 | Batch # 10 Train Loss 0.20203
# Epoch 13 | Batch # 11 Train Loss 0.22488
# Epoch 13 | Batch # 12 Train Loss 0.04912
# Epoch 13 | Batch # 13 Train Loss 0.04922
# Epoch 13 | Batch # 14 Train Loss 0.21258
# Epoch 13 | Batch # 15 Train Loss 0.04004
# Epoch 13 | Batch # 16 Train Loss 0.08343
# Epoch 13 | Batch # 17 Train Loss 0.11168
# Epoch 13 | Batch # 18 Train Loss 0.03745
# Epoch 13 | Batch # 19 Train Loss 0.19880
# Epoch 13 | Batch # 20 Train Loss 0.12361
# Epoch 13 | Batch # 21 Train Loss 0.08782
# Epoch 13 | Batch # 22 Train Loss 0.11559
# Epoch 13 | Batch # 23 Train Loss 0.09345
# Epoch 13 | Batch # 24 Train Loss 0.10100
# Epoch 13 | Epoch Train Loss 0.11243
#
# Epoch 13 | Epoch Train Acc 96.438%
# Epoch 13 | Epoch Val Loss 0.18335
# Epoch 13 | Epoch Val Acc 93.250%
# Epoch 14 | Batch # 0 Train Loss 0.09869
# Epoch 14 | Batch # 1 Train Loss 0.03145
# Epoch 14 | Batch # 2 Train Loss 0.13743
# Epoch 14 | Batch # 3 Train Loss 0.05098
# Epoch 14 | Batch # 4 Train Loss 0.20328
# Epoch 14 | Batch # 5 Train Loss 0.23677
# Epoch 14 | Batch # 6 Train Loss 0.08938
# Epoch 14 | Batch # 7 Train Loss 0.07653
# Epoch 14 | Batch # 8 Train Loss 0.08749
# Epoch 14 | Batch # 9 Train Loss 0.11889
# Epoch 14 | Batch # 10 Train Loss 0.15332
# Epoch 14 | Batch # 11 Train Loss 0.17169
# Epoch 14 | Batch # 12 Train Loss 0.07239
# Epoch 14 | Batch # 13 Train Loss 0.16492
# Epoch 14 | Batch # 14 Train Loss 0.11519
# Epoch 14 | Batch # 15 Train Loss 0.04412
# Epoch 14 | Batch # 16 Train Loss 0.13638
# Epoch 14 | Batch # 17 Train Loss 0.17558
# Epoch 14 | Batch # 18 Train Loss 0.03651
# Epoch 14 | Batch # 19 Train Loss 0.14493
# Epoch 14 | Batch # 20 Train Loss 0.04723
# Epoch 14 | Batch # 21 Train Loss 0.11350
# Epoch 14 | Batch # 22 Train Loss 0.15728
# Epoch 14 | Batch # 23 Train Loss 0.09912
# Epoch 14 | Batch # 24 Train Loss 0.13341
# Epoch 14 | Epoch Train Loss 0.11586
#
# Epoch 14 | Epoch Train Acc 96.625%
# Epoch 14 | Epoch Val Loss 0.17619
# Epoch 14 | Epoch Val Acc 93.750%
# Epoch 15 | Batch # 0 Train Loss 0.04656
# Epoch 15 | Batch # 1 Train Loss 0.16497
# Epoch 15 | Batch # 2 Train Loss 0.02053
# Epoch 15 | Batch # 3 Train Loss 0.11113
# Epoch 15 | Batch # 4 Train Loss 0.06843
# Epoch 15 | Batch # 5 Train Loss 0.09487
# Epoch 15 | Batch # 6 Train Loss 0.04131
# Epoch 15 | Batch # 7 Train Loss 0.09671
# Epoch 15 | Batch # 8 Train Loss 0.20504
# Epoch 15 | Batch # 9 Train Loss 0.19359
# Epoch 15 | Batch # 10 Train Loss 0.46830
# Epoch 15 | Batch # 11 Train Loss 0.04897
# Epoch 15 | Batch # 12 Train Loss 0.22287
# Epoch 15 | Batch # 13 Train Loss 0.04997
# Epoch 15 | Batch # 14 Train Loss 0.24381
# Epoch 15 | Batch # 15 Train Loss 0.22152
# Epoch 15 | Batch # 16 Train Loss 0.08640
# Epoch 15 | Batch # 17 Train Loss 0.22294
# Epoch 15 | Batch # 18 Train Loss 0.09751
# Epoch 15 | Batch # 19 Train Loss 0.25034
# Epoch 15 | Batch # 20 Train Loss 0.05889
# Epoch 15 | Batch # 21 Train Loss 0.07215
# Epoch 15 | Batch # 22 Train Loss 0.12744
# Epoch 15 | Batch # 23 Train Loss 0.07563
# Epoch 15 | Batch # 24 Train Loss 0.17614
# Epoch 15 | Epoch Train Loss 0.13864
#
# Epoch 15 | Epoch Train Acc 95.625%
# Epoch 15 | Epoch Val Loss 0.34192
# Epoch 15 | Epoch Val Acc 91.250%
# Epoch 16 | Batch # 0 Train Loss 0.13263
# Epoch 16 | Batch # 1 Train Loss 0.18634
# Epoch 16 | Batch # 2 Train Loss 0.04386
# Epoch 16 | Batch # 3 Train Loss 0.06474
# Epoch 16 | Batch # 4 Train Loss 0.17244
# Epoch 16 | Batch # 5 Train Loss 0.10305
# Epoch 16 | Batch # 6 Train Loss 0.13496
# Epoch 16 | Batch # 7 Train Loss 0.09004
# Epoch 16 | Batch # 8 Train Loss 0.12321
# Epoch 16 | Batch # 9 Train Loss 0.09841
# Epoch 16 | Batch # 10 Train Loss 0.05773
# Epoch 16 | Batch # 11 Train Loss 0.03717
# Epoch 16 | Batch # 12 Train Loss 0.17535
# Epoch 16 | Batch # 13 Train Loss 0.04101
# Epoch 16 | Batch # 14 Train Loss 0.04624
# Epoch 16 | Batch # 15 Train Loss 0.15680
# Epoch 16 | Batch # 16 Train Loss 0.05732
# Epoch 16 | Batch # 17 Train Loss 0.08331
# Epoch 16 | Batch # 18 Train Loss 0.18196
# Epoch 16 | Batch # 19 Train Loss 0.29184
# Epoch 16 | Batch # 20 Train Loss 0.05303
# Epoch 16 | Batch # 21 Train Loss 0.02298
# Epoch 16 | Batch # 22 Train Loss 0.13814
# Epoch 16 | Batch # 23 Train Loss 0.20181
# Epoch 16 | Batch # 24 Train Loss 0.05724
# Epoch 16 | Epoch Train Loss 0.11006
#
# Epoch 16 | Epoch Train Acc 96.500%
# Epoch 16 | Epoch Val Loss 0.25335
# Epoch 16 | Epoch Val Acc 93.500%
# Epoch 17 | Batch # 0 Train Loss 0.08134
# Epoch 17 | Batch # 1 Train Loss 0.04560
# Epoch 17 | Batch # 2 Train Loss 0.10777
# Epoch 17 | Batch # 3 Train Loss 0.05057
# Epoch 17 | Batch # 4 Train Loss 0.03257
# Epoch 17 | Batch # 5 Train Loss 0.11866
# Epoch 17 | Batch # 6 Train Loss 0.08010
# Epoch 17 | Batch # 7 Train Loss 0.02106
# Epoch 17 | Batch # 8 Train Loss 0.03381
# Epoch 17 | Batch # 9 Train Loss 0.32974
# Epoch 17 | Batch # 10 Train Loss 0.07419
# Epoch 17 | Batch # 11 Train Loss 0.09214
# Epoch 17 | Batch # 12 Train Loss 0.13581
# Epoch 17 | Batch # 13 Train Loss 0.16080
# Epoch 17 | Batch # 14 Train Loss 0.02944
# Epoch 17 | Batch # 15 Train Loss 0.08782
# Epoch 17 | Batch # 16 Train Loss 0.24140
# Epoch 17 | Batch # 17 Train Loss 0.06338
# Epoch 17 | Batch # 18 Train Loss 0.12921
# Epoch 17 | Batch # 19 Train Loss 0.01690
# Epoch 17 | Batch # 20 Train Loss 0.09908
# Epoch 17 | Batch # 21 Train Loss 0.07520
# Epoch 17 | Batch # 22 Train Loss 0.36106
# Epoch 17 | Batch # 23 Train Loss 0.30640
# Epoch 17 | Batch # 24 Train Loss 0.14599
# Epoch 17 | Epoch Train Loss 0.11680
#
# Epoch 17 | Epoch Train Acc 96.188%
# Epoch 17 | Epoch Val Loss 0.28201
# Epoch 17 | Epoch Val Acc 92.250%
# Epoch 18 | Batch # 0 Train Loss 0.03215
# Epoch 18 | Batch # 1 Train Loss 0.13608
# Epoch 18 | Batch # 2 Train Loss 0.09220
# Epoch 18 | Batch # 3 Train Loss 0.23448
# Epoch 18 | Batch # 4 Train Loss 0.10908
# Epoch 18 | Batch # 5 Train Loss 0.09195
# Epoch 18 | Batch # 6 Train Loss 0.32797
# Epoch 18 | Batch # 7 Train Loss 0.08860
# Epoch 18 | Batch # 8 Train Loss 0.10204
# Epoch 18 | Batch # 9 Train Loss 0.10258
# Epoch 18 | Batch # 10 Train Loss 0.49337
# Epoch 18 | Batch # 11 Train Loss 0.06452
# Epoch 18 | Batch # 12 Train Loss 0.14284
# Epoch 18 | Batch # 13 Train Loss 0.03581
# Epoch 18 | Batch # 14 Train Loss 0.21148
# Epoch 18 | Batch # 15 Train Loss 0.28098
# Epoch 18 | Batch # 16 Train Loss 0.12283
# Epoch 18 | Batch # 17 Train Loss 0.28489
# Epoch 18 | Batch # 18 Train Loss 0.12507
# Epoch 18 | Batch # 19 Train Loss 0.13411
# Epoch 18 | Batch # 20 Train Loss 0.29531
# Epoch 18 | Batch # 21 Train Loss 0.22673
# Epoch 18 | Batch # 22 Train Loss 0.23474
# Epoch 18 | Batch # 23 Train Loss 0.19935
# Epoch 18 | Batch # 24 Train Loss 0.16505
# Epoch 18 | Epoch Train Loss 0.17337
#
# Epoch 18 | Epoch Train Acc 95.125%
# Epoch 18 | Epoch Val Loss 0.23425
# Epoch 18 | Epoch Val Acc 92.000%
# Epoch 19 | Batch # 0 Train Loss 0.17108
# Epoch 19 | Batch # 1 Train Loss 0.14685
# Epoch 19 | Batch # 2 Train Loss 0.22871
# Epoch 19 | Batch # 3 Train Loss 0.11495
# Epoch 19 | Batch # 4 Train Loss 0.17414
# Epoch 19 | Batch # 5 Train Loss 0.09602
# Epoch 19 | Batch # 6 Train Loss 0.10610
# Epoch 19 | Batch # 7 Train Loss 0.11365
# Epoch 19 | Batch # 8 Train Loss 0.05539
# Epoch 19 | Batch # 9 Train Loss 0.04913
# Epoch 19 | Batch # 10 Train Loss 0.06495
# Epoch 19 | Batch # 11 Train Loss 0.07590
# Epoch 19 | Batch # 12 Train Loss 0.11633
# Epoch 19 | Batch # 13 Train Loss 0.04647
# Epoch 19 | Batch # 14 Train Loss 0.08583
# Epoch 19 | Batch # 15 Train Loss 0.07333
# Epoch 19 | Batch # 16 Train Loss 0.21603
# Epoch 19 | Batch # 17 Train Loss 0.12251
# Epoch 19 | Batch # 18 Train Loss 0.10822
# Epoch 19 | Batch # 19 Train Loss 0.04843
# Epoch 19 | Batch # 20 Train Loss 0.06883
# Epoch 19 | Batch # 21 Train Loss 0.05863
# Epoch 19 | Batch # 22 Train Loss 0.10125
# Epoch 19 | Batch # 23 Train Loss 0.11494
# Epoch 19 | Batch # 24 Train Loss 0.11391
# Epoch 19 | Epoch Train Loss 0.10686
#
# Epoch 19 | Epoch Train Acc 96.688%
# Epoch 19 | Epoch Val Loss 0.13737
# Epoch 19 | Epoch Val Acc 94.000%
# Epoch 20 | Batch # 0 Train Loss 0.03569
# Epoch 20 | Batch # 1 Train Loss 0.03270
# Epoch 20 | Batch # 2 Train Loss 0.02228
# Epoch 20 | Batch # 3 Train Loss 0.05944
# Epoch 20 | Batch # 4 Train Loss 0.04098
# Epoch 20 | Batch # 5 Train Loss 0.01872
# Epoch 20 | Batch # 6 Train Loss 0.15136
# Epoch 20 | Batch # 7 Train Loss 0.28077
# Epoch 20 | Batch # 8 Train Loss 0.11874
# Epoch 20 | Batch # 9 Train Loss 0.02250
# Epoch 20 | Batch # 10 Train Loss 0.07349
# Epoch 20 | Batch # 11 Train Loss 0.06880
# Epoch 20 | Batch # 12 Train Loss 0.19136
# Epoch 20 | Batch # 13 Train Loss 0.10890
# Epoch 20 | Batch # 14 Train Loss 0.07764
# Epoch 20 | Batch # 15 Train Loss 0.03489
# Epoch 20 | Batch # 16 Train Loss 0.03769
# Epoch 20 | Batch # 17 Train Loss 0.03512
# Epoch 20 | Batch # 18 Train Loss 0.09304
# Epoch 20 | Batch # 19 Train Loss 0.06646
# Epoch 20 | Batch # 20 Train Loss 0.04487
# Epoch 20 | Batch # 21 Train Loss 0.04194
# Epoch 20 | Batch # 22 Train Loss 0.03848
# Epoch 20 | Batch # 23 Train Loss 0.08792
# Epoch 20 | Batch # 24 Train Loss 0.04941
# Epoch 20 | Epoch Train Loss 0.07333
#
# Epoch 20 | Epoch Train Acc 97.438%
# Epoch 20 | Epoch Val Loss 0.30288
# Epoch 20 | Epoch Val Acc 93.750%
# Epoch 21 | Batch # 0 Train Loss 0.14595
# Epoch 21 | Batch # 1 Train Loss 0.18466
# Epoch 21 | Batch # 2 Train Loss 0.00866
# Epoch 21 | Batch # 3 Train Loss 0.01797
# Epoch 21 | Batch # 4 Train Loss 0.08237
# Epoch 21 | Batch # 5 Train Loss 0.06890
# Epoch 21 | Batch # 6 Train Loss 0.14918
# Epoch 21 | Batch # 7 Train Loss 0.17052
# Epoch 21 | Batch # 8 Train Loss 0.18009
# Epoch 21 | Batch # 9 Train Loss 0.06458
# Epoch 21 | Batch # 10 Train Loss 0.08254
# Epoch 21 | Batch # 11 Train Loss 0.04896
# Epoch 21 | Batch # 12 Train Loss 0.03979
# Epoch 21 | Batch # 13 Train Loss 0.13080
# Epoch 21 | Batch # 14 Train Loss 0.11216
# Epoch 21 | Batch # 15 Train Loss 0.16603
# Epoch 21 | Batch # 16 Train Loss 0.07161
# Epoch 21 | Batch # 17 Train Loss 0.14601
# Epoch 21 | Batch # 18 Train Loss 0.07456
# Epoch 21 | Batch # 19 Train Loss 0.06251
# Epoch 21 | Batch # 20 Train Loss 0.08131
# Epoch 21 | Batch # 21 Train Loss 0.05880
# Epoch 21 | Batch # 22 Train Loss 0.06887
# Epoch 21 | Batch # 23 Train Loss 0.02562
# Epoch 21 | Batch # 24 Train Loss 0.07677
# Epoch 21 | Epoch Train Loss 0.09277
#
# Epoch 21 | Epoch Train Acc 96.875%
# Epoch 21 | Epoch Val Loss 0.40169
# Epoch 21 | Epoch Val Acc 89.500%
# Epoch 22 | Batch # 0 Train Loss 0.08706
# Epoch 22 | Batch # 1 Train Loss 0.09137
# Epoch 22 | Batch # 2 Train Loss 0.21012
# Epoch 22 | Batch # 3 Train Loss 0.06805
# Epoch 22 | Batch # 4 Train Loss 0.02064
# Epoch 22 | Batch # 5 Train Loss 0.02894
# Epoch 22 | Batch # 6 Train Loss 0.04972
# Epoch 22 | Batch # 7 Train Loss 0.07645
# Epoch 22 | Batch # 8 Train Loss 0.06799
# Epoch 22 | Batch # 9 Train Loss 0.02370
# Epoch 22 | Batch # 10 Train Loss 0.02517
# Epoch 22 | Batch # 11 Train Loss 0.17431
# Epoch 22 | Batch # 12 Train Loss 0.16567
# Epoch 22 | Batch # 13 Train Loss 0.08854
# Epoch 22 | Batch # 14 Train Loss 0.04859
# Epoch 22 | Batch # 15 Train Loss 0.04997
# Epoch 22 | Batch # 16 Train Loss 0.03980
# Epoch 22 | Batch # 17 Train Loss 0.01667
# Epoch 22 | Batch # 18 Train Loss 0.03499
# Epoch 22 | Batch # 19 Train Loss 0.03330
# Epoch 22 | Batch # 20 Train Loss 0.13043
# Epoch 22 | Batch # 21 Train Loss 0.17851
# Epoch 22 | Batch # 22 Train Loss 0.13008
# Epoch 22 | Batch # 23 Train Loss 0.08847
# Epoch 22 | Batch # 24 Train Loss 0.07789
# Epoch 22 | Epoch Train Loss 0.08026
#
# Epoch 22 | Epoch Train Acc 97.125%
# Epoch 22 | Epoch Val Loss 0.16663
# Epoch 22 | Epoch Val Acc 95.500%
# Epoch 23 | Batch # 0 Train Loss 0.01338
# Epoch 23 | Batch # 1 Train Loss 0.12923
# Epoch 23 | Batch # 2 Train Loss 0.11183
# Epoch 23 | Batch # 3 Train Loss 0.05594
# Epoch 23 | Batch # 4 Train Loss 0.09326
# Epoch 23 | Batch # 5 Train Loss 0.09314
# Epoch 23 | Batch # 6 Train Loss 0.12102
# Epoch 23 | Batch # 7 Train Loss 0.10251
# Epoch 23 | Batch # 8 Train Loss 0.06467
# Epoch 23 | Batch # 9 Train Loss 0.02490
# Epoch 23 | Batch # 10 Train Loss 0.15747
# Epoch 23 | Batch # 11 Train Loss 0.07406
# Epoch 23 | Batch # 12 Train Loss 0.18218
# Epoch 23 | Batch # 13 Train Loss 0.02843
# Epoch 23 | Batch # 14 Train Loss 0.05228
# Epoch 23 | Batch # 15 Train Loss 0.03962
# Epoch 23 | Batch # 16 Train Loss 0.10543
# Epoch 23 | Batch # 17 Train Loss 0.06814
# Epoch 23 | Batch # 18 Train Loss 0.10109
# Epoch 23 | Batch # 19 Train Loss 0.22635
# Epoch 23 | Batch # 20 Train Loss 0.02572
# Epoch 23 | Batch # 21 Train Loss 0.04082
# Epoch 23 | Batch # 22 Train Loss 0.14532
# Epoch 23 | Batch # 23 Train Loss 0.04424
# Epoch 23 | Batch # 24 Train Loss 0.02511
# Epoch 23 | Epoch Train Loss 0.08504
#
# Epoch 23 | Epoch Train Acc 97.312%
# Epoch 23 | Epoch Val Loss 0.12100
# Epoch 23 | Epoch Val Acc 95.750%
# Epoch 24 | Batch # 0 Train Loss 0.04468
# Epoch 24 | Batch # 1 Train Loss 0.04989
# Epoch 24 | Batch # 2 Train Loss 0.08688
# Epoch 24 | Batch # 3 Train Loss 0.02810
# Epoch 24 | Batch # 4 Train Loss 0.06611
# Epoch 24 | Batch # 5 Train Loss 0.06440
# Epoch 24 | Batch # 6 Train Loss 0.06580
# Epoch 24 | Batch # 7 Train Loss 0.03837
# Epoch 24 | Batch # 8 Train Loss 0.01969
# Epoch 24 | Batch # 9 Train Loss 0.03255
# Epoch 24 | Batch # 10 Train Loss 0.08587
# Epoch 24 | Batch # 11 Train Loss 0.04093
# Epoch 24 | Batch # 12 Train Loss 0.20815
# Epoch 24 | Batch # 13 Train Loss 0.13737
# Epoch 24 | Batch # 14 Train Loss 0.03872
# Epoch 24 | Batch # 15 Train Loss 0.05228
# Epoch 24 | Batch # 16 Train Loss 0.05234
# Epoch 24 | Batch # 17 Train Loss 0.02858
# Epoch 24 | Batch # 18 Train Loss 0.03738
# Epoch 24 | Batch # 19 Train Loss 0.03788
# Epoch 24 | Batch # 20 Train Loss 0.41007
# Epoch 24 | Batch # 21 Train Loss 0.11259
# Epoch 24 | Batch # 22 Train Loss 0.04575
# Epoch 24 | Batch # 23 Train Loss 0.04062
# Epoch 24 | Batch # 24 Train Loss 0.01494
# Epoch 24 | Epoch Train Loss 0.07360
#
# Epoch 24 | Epoch Train Acc 97.375%
# Epoch 24 | Epoch Val Loss 0.24423
# Epoch 24 | Epoch Val Acc 90.250%
# Epoch 25 | Batch # 0 Train Loss 0.02667
# Epoch 25 | Batch # 1 Train Loss 0.07353
# Epoch 25 | Batch # 2 Train Loss 0.10477
# Epoch 25 | Batch # 3 Train Loss 0.18719
# Epoch 25 | Batch # 4 Train Loss 0.06749
# Epoch 25 | Batch # 5 Train Loss 0.31715
# Epoch 25 | Batch # 6 Train Loss 0.15839
# Epoch 25 | Batch # 7 Train Loss 0.12920
# Epoch 25 | Batch # 8 Train Loss 0.06661
# Epoch 25 | Batch # 9 Train Loss 0.01728
# Epoch 25 | Batch # 10 Train Loss 0.07681
# Epoch 25 | Batch # 11 Train Loss 0.14102
# Epoch 25 | Batch # 12 Train Loss 0.19851
# Epoch 25 | Batch # 13 Train Loss 0.10382
# Epoch 25 | Batch # 14 Train Loss 0.25750
# Epoch 25 | Batch # 15 Train Loss 0.04878
# Epoch 25 | Batch # 16 Train Loss 0.21627
# Epoch 25 | Batch # 17 Train Loss 0.42116
# Epoch 25 | Batch # 18 Train Loss 0.08742
# Epoch 25 | Batch # 19 Train Loss 0.05980
# Epoch 25 | Batch # 20 Train Loss 0.25760
# Epoch 25 | Batch # 21 Train Loss 0.16979
# Epoch 25 | Batch # 22 Train Loss 0.02995
# Epoch 25 | Batch # 23 Train Loss 0.16781
# Epoch 25 | Batch # 24 Train Loss 0.09206
# Epoch 25 | Epoch Train Loss 0.13906
#
# Epoch 25 | Epoch Train Acc 95.875%
# Epoch 25 | Epoch Val Loss 0.19632
# Epoch 25 | Epoch Val Acc 94.500%
# Epoch 26 | Batch # 0 Train Loss 0.01813
# Epoch 26 | Batch # 1 Train Loss 0.12793
# Epoch 26 | Batch # 2 Train Loss 0.13268
# Epoch 26 | Batch # 3 Train Loss 0.11381
# Epoch 26 | Batch # 4 Train Loss 0.10286
# Epoch 26 | Batch # 5 Train Loss 0.19209
# Epoch 26 | Batch # 6 Train Loss 0.04806
# Epoch 26 | Batch # 7 Train Loss 0.07533
# Epoch 26 | Batch # 8 Train Loss 0.03827
# Epoch 26 | Batch # 9 Train Loss 0.05966
# Epoch 26 | Batch # 10 Train Loss 0.02884
# Epoch 26 | Batch # 11 Train Loss 0.10754
# Epoch 26 | Batch # 12 Train Loss 0.08998
# Epoch 26 | Batch # 13 Train Loss 0.10519
# Epoch 26 | Batch # 14 Train Loss 0.08151
# Epoch 26 | Batch # 15 Train Loss 0.02819
# Epoch 26 | Batch # 16 Train Loss 0.10137
# Epoch 26 | Batch # 17 Train Loss 0.19996
# Epoch 26 | Batch # 18 Train Loss 0.08155
# Epoch 26 | Batch # 19 Train Loss 0.02053
# Epoch 26 | Batch # 20 Train Loss 0.12851
# Epoch 26 | Batch # 21 Train Loss 0.08125
# Epoch 26 | Batch # 22 Train Loss 0.07381
# Epoch 26 | Batch # 23 Train Loss 0.01843
# Epoch 26 | Batch # 24 Train Loss 0.01800
# Epoch 26 | Epoch Train Loss 0.08294
#
# Epoch 26 | Epoch Train Acc 97.062%
# Epoch 26 | Epoch Val Loss 0.20013
# Epoch 26 | Epoch Val Acc 94.750%
# Epoch 27 | Batch # 0 Train Loss 0.02734
# Epoch 27 | Batch # 1 Train Loss 0.05945
# Epoch 27 | Batch # 2 Train Loss 0.08088
# Epoch 27 | Batch # 3 Train Loss 0.02315
# Epoch 27 | Batch # 4 Train Loss 0.03671
# Epoch 27 | Batch # 5 Train Loss 0.05501
# Epoch 27 | Batch # 6 Train Loss 0.03026
# Epoch 27 | Batch # 7 Train Loss 0.02926
# Epoch 27 | Batch # 8 Train Loss 0.00851
# Epoch 27 | Batch # 9 Train Loss 0.10334
# Epoch 27 | Batch # 10 Train Loss 0.08931
# Epoch 27 | Batch # 11 Train Loss 0.00495
# Epoch 27 | Batch # 12 Train Loss 0.00586
# Epoch 27 | Batch # 13 Train Loss 0.04261
# Epoch 27 | Batch # 14 Train Loss 0.02140
# Epoch 27 | Batch # 15 Train Loss 0.00864
# Epoch 27 | Batch # 16 Train Loss 0.02942
# Epoch 27 | Batch # 17 Train Loss 0.02562
# Epoch 27 | Batch # 18 Train Loss 0.02373
# Epoch 27 | Batch # 19 Train Loss 0.06782
# Epoch 27 | Batch # 20 Train Loss 0.04330
# Epoch 27 | Batch # 21 Train Loss 0.15524
# Epoch 27 | Batch # 22 Train Loss 0.02246
# Epoch 27 | Batch # 23 Train Loss 0.02783
# Epoch 27 | Batch # 24 Train Loss 0.01382
# Epoch 27 | Epoch Train Loss 0.04144
#
# Epoch 27 | Epoch Train Acc 98.812%
# Epoch 27 | Epoch Val Loss 0.13368
# Epoch 27 | Epoch Val Acc 94.000%
# Epoch 28 | Batch # 0 Train Loss 0.01210
# Epoch 28 | Batch # 1 Train Loss 0.01833
# Epoch 28 | Batch # 2 Train Loss 0.10294
# Epoch 28 | Batch # 3 Train Loss 0.03729
# Epoch 28 | Batch # 4 Train Loss 0.03444
# Epoch 28 | Batch # 5 Train Loss 0.03722
# Epoch 28 | Batch # 6 Train Loss 0.01148
# Epoch 28 | Batch # 7 Train Loss 0.02438
# Epoch 28 | Batch # 8 Train Loss 0.03647
# Epoch 28 | Batch # 9 Train Loss 0.08414
# Epoch 28 | Batch # 10 Train Loss 0.03162
# Epoch 28 | Batch # 11 Train Loss 0.05651
# Epoch 28 | Batch # 12 Train Loss 0.00288
# Epoch 28 | Batch # 13 Train Loss 0.01889
# Epoch 28 | Batch # 14 Train Loss 0.01000
# Epoch 28 | Batch # 15 Train Loss 0.00600
# Epoch 28 | Batch # 16 Train Loss 0.15409
# Epoch 28 | Batch # 17 Train Loss 0.00155
# Epoch 28 | Batch # 18 Train Loss 0.02108
# Epoch 28 | Batch # 19 Train Loss 0.01780
# Epoch 28 | Batch # 20 Train Loss 0.23485
# Epoch 28 | Batch # 21 Train Loss 0.08363
# Epoch 28 | Batch # 22 Train Loss 0.14027
# Epoch 28 | Batch # 23 Train Loss 0.06917
# Epoch 28 | Batch # 24 Train Loss 0.04753
# Epoch 28 | Epoch Train Loss 0.05179
#
# Epoch 28 | Epoch Train Acc 98.438%
# Epoch 28 | Epoch Val Loss 0.19693
# Epoch 28 | Epoch Val Acc 93.750%
# Epoch 29 | Batch # 0 Train Loss 0.00334
# Epoch 29 | Batch # 1 Train Loss 0.00465
# Epoch 29 | Batch # 2 Train Loss 0.01629
# Epoch 29 | Batch # 3 Train Loss 0.00436
# Epoch 29 | Batch # 4 Train Loss 0.06089
# Epoch 29 | Batch # 5 Train Loss 0.03845
# Epoch 29 | Batch # 6 Train Loss 0.01974
# Epoch 29 | Batch # 7 Train Loss 0.33144
# Epoch 29 | Batch # 8 Train Loss 0.05979
# Epoch 29 | Batch # 9 Train Loss 0.02592
# Epoch 29 | Batch # 10 Train Loss 0.14093
# Epoch 29 | Batch # 11 Train Loss 0.05567
# Epoch 29 | Batch # 12 Train Loss 0.11397
# Epoch 29 | Batch # 13 Train Loss 0.27109
# Epoch 29 | Batch # 14 Train Loss 0.12638
# Epoch 29 | Batch # 15 Train Loss 0.04905
# Epoch 29 | Batch # 16 Train Loss 0.05189
# Epoch 29 | Batch # 17 Train Loss 0.05262
# Epoch 29 | Batch # 18 Train Loss 0.27323
# Epoch 29 | Batch # 19 Train Loss 0.05628
# Epoch 29 | Batch # 20 Train Loss 0.06319
# Epoch 29 | Batch # 21 Train Loss 0.11078
# Epoch 29 | Batch # 22 Train Loss 0.06746
# Epoch 29 | Batch # 23 Train Loss 0.10247
# Epoch 29 | Batch # 24 Train Loss 0.12087
# Epoch 29 | Epoch Train Loss 0.08883
#
# Epoch 29 | Epoch Train Acc 96.938%
# Epoch 29 | Epoch Val Loss 0.30958
# Epoch 29 | Epoch Val Acc 91.750%
# Epoch 30 | Batch # 0 Train Loss 0.10075
# Epoch 30 | Batch # 1 Train Loss 0.03050
# Epoch 30 | Batch # 2 Train Loss 0.07365
# Epoch 30 | Batch # 3 Train Loss 0.06827
# Epoch 30 | Batch # 4 Train Loss 0.02736
# Epoch 30 | Batch # 5 Train Loss 0.10851
# Epoch 30 | Batch # 6 Train Loss 0.30456
# Epoch 30 | Batch # 7 Train Loss 0.03315
# Epoch 30 | Batch # 8 Train Loss 0.13030
# Epoch 30 | Batch # 9 Train Loss 0.12887
# Epoch 30 | Batch # 10 Train Loss 0.03470
# Epoch 30 | Batch # 11 Train Loss 0.16650
# Epoch 30 | Batch # 12 Train Loss 0.18151
# Epoch 30 | Batch # 13 Train Loss 0.03979
# Epoch 30 | Batch # 14 Train Loss 0.06200
# Epoch 30 | Batch # 15 Train Loss 0.15044
# Epoch 30 | Batch # 16 Train Loss 0.05836
# Epoch 30 | Batch # 17 Train Loss 0.25343
# Epoch 30 | Batch # 18 Train Loss 0.06238
# Epoch 30 | Batch # 19 Train Loss 0.10763
# Epoch 30 | Batch # 20 Train Loss 0.09687
# Epoch 30 | Batch # 21 Train Loss 0.03535
# Epoch 30 | Batch # 22 Train Loss 0.13570
# Epoch 30 | Batch # 23 Train Loss 0.04970
# Epoch 30 | Batch # 24 Train Loss 0.06534
# Epoch 30 | Epoch Train Loss 0.10023
#
# Epoch 30 | Epoch Train Acc 96.625%
# Epoch 30 | Epoch Val Loss 0.21710
# Epoch 30 | Epoch Val Acc 91.750%
# Epoch 31 | Batch # 0 Train Loss 0.03702
# Epoch 31 | Batch # 1 Train Loss 0.13485
# Epoch 31 | Batch # 2 Train Loss 0.02459
# Epoch 31 | Batch # 3 Train Loss 0.05645
# Epoch 31 | Batch # 4 Train Loss 0.03244
# Epoch 31 | Batch # 5 Train Loss 0.06384
# Epoch 31 | Batch # 6 Train Loss 0.01878
# Epoch 31 | Batch # 7 Train Loss 0.03783
# Epoch 31 | Batch # 8 Train Loss 0.01773
# Epoch 31 | Batch # 9 Train Loss 0.03358
# Epoch 31 | Batch # 10 Train Loss 0.11463
# Epoch 31 | Batch # 11 Train Loss 0.01067
# Epoch 31 | Batch # 12 Train Loss 0.07549
# Epoch 31 | Batch # 13 Train Loss 0.04214
# Epoch 31 | Batch # 14 Train Loss 0.12219
# Epoch 31 | Batch # 15 Train Loss 0.02657
# Epoch 31 | Batch # 16 Train Loss 0.10996
# Epoch 31 | Batch # 17 Train Loss 0.17946
# Epoch 31 | Batch # 18 Train Loss 0.06015
# Epoch 31 | Batch # 19 Train Loss 0.09766
# Epoch 31 | Batch # 20 Train Loss 0.16251
# Epoch 31 | Batch # 21 Train Loss 0.04629
# Epoch 31 | Batch # 22 Train Loss 0.07501
# Epoch 31 | Batch # 23 Train Loss 0.19143
# Epoch 31 | Batch # 24 Train Loss 0.10634
# Epoch 31 | Epoch Train Loss 0.07511
#
# Epoch 31 | Epoch Train Acc 97.188%
# Epoch 31 | Epoch Val Loss 0.20112
# Epoch 31 | Epoch Val Acc 94.500%
# Epoch 32 | Batch # 0 Train Loss 0.05155
# Epoch 32 | Batch # 1 Train Loss 0.02383
# Epoch 32 | Batch # 2 Train Loss 0.04048
# Epoch 32 | Batch # 3 Train Loss 0.03161
# Epoch 32 | Batch # 4 Train Loss 0.12228
# Epoch 32 | Batch # 5 Train Loss 0.06878
# Epoch 32 | Batch # 6 Train Loss 0.00366
# Epoch 32 | Batch # 7 Train Loss 0.02691
# Epoch 32 | Batch # 8 Train Loss 0.03378
# Epoch 32 | Batch # 9 Train Loss 0.05252
# Epoch 32 | Batch # 10 Train Loss 0.50529
# Epoch 32 | Batch # 11 Train Loss 0.03747
# Epoch 32 | Batch # 12 Train Loss 0.06814
# Epoch 32 | Batch # 13 Train Loss 0.03232
# Epoch 32 | Batch # 14 Train Loss 0.12130
# Epoch 32 | Batch # 15 Train Loss 0.06435
# Epoch 32 | Batch # 16 Train Loss 0.02810
# Epoch 32 | Batch # 17 Train Loss 0.03190
# Epoch 32 | Batch # 18 Train Loss 0.05936
# Epoch 32 | Batch # 19 Train Loss 0.01958
# Epoch 32 | Batch # 20 Train Loss 0.07931
# Epoch 32 | Batch # 21 Train Loss 0.00517
# Epoch 32 | Batch # 22 Train Loss 0.01668
# Epoch 32 | Batch # 23 Train Loss 0.03609
# Epoch 32 | Batch # 24 Train Loss 0.00808
# Epoch 32 | Epoch Train Loss 0.06274
#
# Epoch 32 | Epoch Train Acc 98.312%
# Epoch 32 | Epoch Val Loss 0.19265
# Epoch 32 | Epoch Val Acc 93.750%
# Epoch 33 | Batch # 0 Train Loss 0.05487
# Epoch 33 | Batch # 1 Train Loss 0.05874
# Epoch 33 | Batch # 2 Train Loss 0.00492
# Process Process-67:
# Traceback (most recent call last):
#   File "/data/tennant/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/data/tennant/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/data/tennant/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 106, in _worker_loop
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/data/tennant/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 106, in <listcomp>
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/data/tennant/data-competitions/dianshi_TG/data.py", line 39, in __getitem__
#     img = self._im_read(self.img_path + self.X_train[index] + self.img_ext)
#   File "/data/tennant/data-competitions/dianshi_TG/data.py", line 36, in _im_read
#     return img.convert('RGB')
#   File "/data/tennant/anaconda3/envs/pytorch/lib/python3.6/site-packages/PIL/Image.py", line 899, in convert
#     self.load()
#   File "/data/tennant/anaconda3/envs/pytorch/lib/python3.6/site-packages/PIL/ImageFile.py", line 239, in load
#     n, err_code = decoder.decode(b)
# KeyboardInterrupt
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Epoch 33 | Batch # 3 Train Loss 0.01491
# Traceback (most recent call last):
#   File "/data/tennant/anaconda3/envs/pytorch/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3265, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-8-0e134cc16d4d>", line 9, in <module>
#     for batch_idx, (X_train, y_train) in enumerate(train_loader):
#   File "/data/tennant/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 330, in __next__
#     idx, batch = self._get_batch()
#   File "/data/tennant/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 309, in _get_batch
#     return self.data_queue.get()
#   File "/data/tennant/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 342, in get
#     res = self._reader.recv_bytes()
#   File "/data/tennant/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/data/tennant/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/data/tennant/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/data/tennant/anaconda3/envs/pytorch/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2016, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/data/tennant/anaconda3/envs/pytorch/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1095, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/data/tennant/anaconda3/envs/pytorch/lib/python3.6/site-packages/IPython/core/ultratb.py", line 313, in wrapped
#     return f(*args, **kwargs)
#   File "/data/tennant/anaconda3/envs/pytorch/lib/python3.6/site-packages/IPython/core/ultratb.py", line 347, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/data/tennant/anaconda3/envs/pytorch/lib/python3.6/inspect.py", line 1480, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/data/tennant/anaconda3/envs/pytorch/lib/python3.6/inspect.py", line 1438, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/data/tennant/anaconda3/envs/pytorch/lib/python3.6/inspect.py", line 693, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/data/tennant/anaconda3/envs/pytorch/lib/python3.6/inspect.py", line 739, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "/data/tennant/anaconda3/envs/pytorch/lib/python3.6/posixpath.py", line 386, in realpath
#     path, ok = _joinrealpath(filename[:0], filename, {})
#   File "/data/tennant/anaconda3/envs/pytorch/lib/python3.6/posixpath.py", line 419, in _joinrealpath
#     newpath = join(path, name)
#   File "/data/tennant/anaconda3/envs/pytorch/lib/python3.6/posixpath.py", line 84, in join
#     for b in map(os.fspath, p):
#   File "/data/tennant/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 227, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 74866) exited unexpectedly with exit code 1. Details are lost due to multiprocessing. Rerunning with num_workers=0 may give better error trace.
# ---------------------------------------------------------------------------

# %%
plt.rcParams['figure.figsize'] = (10.0, 8.0) 
plt.subplot(2,1,1)
plt.plot(train_loss_rec, 'b')
plt.plot(test_loss_rec, 'r')

plt.title('loss')
plt.xlabel('Epoch')

plt.legend(['Train loss', 'Validation loss'], loc=4)

plt.subplot(2,1,2)
plt.plot(train_acc_rec, 'b')
plt.plot(test_acc_rec, 'r')

plt.title('Prediction Accuracy')
plt.xlabel('Epoch')

plt.legend(['Train prediction accuracy' ,'Validation prediction accuracy'], loc=4)
plt.show()
